# %% [markdown]
# ## 練習時間
# #### 請寫一個函式用來計算 Mean Square Error
# $ MSE = \frac{1}{n}\sum_{i=1}^{n}{(Y_i - \hat{Y}_i)^2} $
#
# ### Hint: [如何取平方](https://googoodesign.gitbooks.io/-ezpython/unit-1.html)

# %% [markdown]
# # [作業目標]
# - 仿造範例的MAE函數, 自己寫一個MSE函數(參考上面公式)

# %% [markdown]
# # [作業重點]
# - 注意程式的縮排
# - 是否能將數學公式, 轉換為 Python 的函式組合? (In[2], Out[2])

# %%
# 載入基礎套件與代稱
import numpy as np
import matplotlib.pyplot as plt

# %%
def mean_absolute_error(y, yp):
    """
    計算 MAE
    Args:
        - y: 實際值
        - yp: 預測值
    Return:
        - mae: MAE
    """
    mae = MAE = sum(abs(y - yp)) / len(y)
    return mae

# 定義 mean_squared_error 這個函數, 計算並傳回 MSE
def mean_squared_error(y, yp):
    """
    請完成這個 Function 後往下執行
    """
    mse = MSE = sum((y-yp)**2) / len(y)
    return mse

# %%
# 與範例相同, 不另外解說
w = 3
b = 0.5
x_lin = np.linspace(0, 100, 101)
y = (x_lin + np.random.randn(101) * 5) * w + b

plt.plot(x_lin, y, 'b.', label = 'data points')
plt.title("Assume we have data points")
plt.legend(loc = 2)
plt.show()

# %%
# 與範例相同, 不另外解說
y_hat = x_lin * w + b
plt.plot(x_lin, y, 'b.', label = 'data')
plt.plot(x_lin, y_hat, 'r-', label = 'prediction')
plt.title("Assume we have data points (And the prediction)")
plt.legend(loc = 2)
plt.show()

# %%
# 執行 Function, 確認有沒有正常執行
MSE = mean_squared_error(y, y_hat)
MAE = mean_absolute_error(y, y_hat)
print("The Mean squared error is %.3f" % (MSE))
print("The Mean absolute error is %.3f" % (MAE))
# Out:
# The Mean squared error is 153.519
# The Mean absolute error is 9.827

# %% [markdown]
# # [作業2]
#
# 請上 Kaggle, 在 Competitions 或 Dataset 中找一組競賽或資料並寫下：
#
# 1. 你選的這組資料為何重要
#
# 2. 資料從何而來 (tips: 譬如提供者是誰、以什麼方式蒐集)
#
# 3. 蒐集而來的資料型態為何
#
# 4. 這組資料想解決的問題如何評估
#
# # [作業3]
#
# 想像你經營一個自由載客車隊，你希望能透過數據分析以提升業績，請你思考並描述你如何規劃整體的分析/解決方案：
#
# 1. 核心問題為何 (tips：如何定義 「提升業績 & 你的假設」)
#
# 2. 資料從何而來 (tips：哪些資料可能會對你想問的問題產生影響 & 資料如何蒐集)
#
# 3. 蒐集而來的資料型態為何
#
# 4. 你要回答的問題，其如何評估 (tips：你的假設如何驗證)

# %% [markdown]
# # [作業2]- Answer
#
# 選取的data為 Kaggle dataset當中的"movie lens"
#
# 1. 這筆dataset收集了約3900部電影的1,000,209個匿名評分。這當中提供了評分人的年齡區間、該電影的評分、該電影的類別等數據。根據以上幾個所提供的資料，可以統計出何者類型的電影較受哪個年齡層喜愛、何種類型的電影評分較高等資訊。在影視業做此分析，則可針對目標族群去研究他們的喜好，以此為大方向來進行電影或影集的拍攝，藉此取得更好的票房。
#
# 2. 這筆資料是University of Minnesota中的資工系所做的研究，資料來源主要是從grouplens網站當中的movielens這一類別所收集而來。
#
# 3. 資料型態主要有String與Numeric兩種。在電影的描述上主要使用String，電影類別是使用Numeric的方式，存成dummy variable。而其他例如電影評分、使用者的數據(ex.年齡)則都是用Numeric的形式儲存。
#
# 4.  利用以上的數據建立預測模型，再將預計要拍攝的電影所設想好的方向參數(ex.類別、目標族群等)放入，檢視得出來的評分是否有達到一定的閾值。若有則便可預期有一定程度的製作價值，但因影視部分還牽涉到許多參數，如：演員、製作團隊、導演等因素，可能結果仍會有所偏差。

# %% [markdown]
# # [作業3]-Answer
#
# 1. 目前的載客狀況為何。提升業績的指標設定為：(總收益-油錢)/載客次數。若是這個指標有所下降，代表平均花費載客上的金額較少，可以預期收益也會變高。假設在載客量不變的情況下，降低油錢的花費。
#
# 2. 載客的地點、司機載客量、每隔多久載一次客、每個月花費在加油上多少錢、總工時多長。資料可以藉由司機手機當中的APP做紀錄，手機上下班時打卡，便可記錄總工時長。每一次載客時，都在APP上登錄資料。可以結合手機GPS的功能，紀錄載客地點、行駛距離長度等。
#
# 3. 大多都為Numeric的資料型態。地點則使用String表示。
#
# 4. 分析統整上述數據後，可以觀察到何處的載客量平均較多，便可在這部份多安排些人手。另外則是可以推廣APP以及電話叫車等服務，利用GPS系統找到最近的車輛，便可以減去載客時跑遠距離的問題，或著是沒有客人時可能會在城市裏頭行駛，降低油錢的花費。若是政策實行後，在幾個月內，提升業績的指標若有顯著下降的話，則可代表這樣的政策與改變在統計學中是被視為有效的。
